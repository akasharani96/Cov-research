# %% [markdown]
# ### Genomic Diversity Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

t_filenameTSV=r'C:\Users\Akash\Desktop\Samples\variant_list.tsv'
tsv_read2= pd.read_csv(t_filenameTSV, sep='\t')
b=tsv_read2.values

genposition2_values=b[:,2] 
positions2=Counter(genposition2_values).keys() 
uniquevals=len(list(positions2))
binsval2=30000

samples=Counter(b[:,0]).keys()

print("There are ",len(genposition2_values), " position values")
print("However there are ",uniquevals, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs2 = dict(alpha=0.5, bins=binsval2)
plt.hist(genposition2_values, **kwargs2)
plt.ylim(0,400)
plt.title("Histogram of genome positions")
plt.show()

df1 = pd.Series(genposition2_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df1.columns = ['Position', 'Frequency']
print (df1)
# Out:
# There are  895987  position values
# However there are  29343  unique position values
# There are  2374  unique samples
#        Position  Frequency
# 0            10          2
# 1            12          1
# 2            13          1
# 3            14          1
# 4            19          2
# ...         ...        ...
# 29338     29861          1
# 29339     29864          1
# 29340     29867          1
# 29341     29868          1
# 29342     29870          3
#
# [29343 rows x 2 columns]

# %% [markdown]
# ### 5% to 95% AF

# %%
import numpy as np
m = [row for row in b if row[7]<=0.95]
q = [row for row in m if row[7]>=0.05]
qdata=np.array(q)

freq_values=qdata[:,7]
print(freq_values)
## all values are between 5% and 95% AF
# Out:
# [0.937107 0.05128200000000001 0.067729 ... 0.943342 0.062127999999999996
#  0.074563]

# %%
genposition3_values=qdata[:,2] 
positions3=Counter(genposition3_values).keys() 
uniquevals3=len(list(positions3))
binsval3=30000
samples=Counter(qdata[:,0]).keys()

samples=Counter(qdata[:,0]).keys()

print("There are ",len(genposition3_values), " position values")
print("However there are ",uniquevals3, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs3 = dict(alpha=0.5, bins=binsval3)
plt.hist(genposition3_values, **kwargs3)
plt.ylim(0,150)
plt.title("Histogram of genome positions 5%-95%")
plt.show()

df3 = pd.Series(genposition3_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df3.columns = ['Position', 'Frequency']
print (df3)
# Out:
# There are  76475  position values
# However there are  14164  unique position values
# There are  1913  unique samples
#        Position  Frequency
# 0            27          1
# 1            30          2
# 2            34          1
# 3            39          2
# 4            40          1
# ...         ...        ...
# 14159     29836         23
# 14160     29837          8
# 14161     29839          2
# 14162     29867          1
# 14163     29870          2
#
# [14164 rows x 2 columns]

# %% [markdown]
# ### 5% to 50% AF

# %%
import numpy as np
m = [row for row in b if row[7]<=0.50]
q = [row for row in m if row[7]>=0.05]
qdata=np.array(q)

freq_values=qdata[:,7]
print(freq_values)
## all values are between 5% and 95% AF
# Out:
# [0.05128200000000001 0.067729 0.056399 ... 0.074048 0.062127999999999996
#  0.074563]

# %%
genposition3_values=qdata[:,2] 
positions3=Counter(genposition3_values).keys() 
uniquevals3=len(list(positions3))
binsval3=30000
samples=Counter(qdata[:,0]).keys()

samples=Counter(qdata[:,0]).keys()

print("There are ",len(genposition3_values), " position values")
print("However there are ",uniquevals3, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs3 = dict(alpha=0.5, bins=binsval3)
plt.hist(genposition3_values,bins=30000)
plt.ylim(0,150)
plt.title("Histogram of genome positions 5%-50%")
plt.show()

df3 = pd.Series(genposition3_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df3.columns = ['Position', 'Frequency']
print (df3) 
df3.sort_values('Frequency')
# Out:
# There are  70352  position values
# However there are  13882  unique position values
# There are  1553  unique samples
#        Position  Frequency
# 0            27          1
# 1            30          2
# 2            34          1
# 3            39          1
# 4            40          1
# ...         ...        ...
# 13877     29835         28
# 13878     29836         23
# 13879     29837          8
# 13880     29839          2
# 13881     29870          2
#
# [13882 rows x 2 columns]
#       Position  Frequency
# 0           27          1
# 4222      9429          1
# 4221      9428          1
# 4219      9425          1
# 4218      9423          1
# ...        ...        ...
# 7887     17096        127
# 7263     15769        127
# 5555     12164        142
# 260        558        149
# 6705     14548        157
#
# [13882 rows x 2 columns]

# %%
df3.Frequency.argmax()
df3.plot.scatter('Position','Frequency')

# %%
x=Counter(genposition3_values)
print(x)
# Out:
# Counter({14548: 157, 558: 149, 12164: 142, 17096: 127, 15769: 127, 24557: 127, 28079: 127, 10986: 123, 2036: 122, 24933: 120, 7038: 114, 9141: 114, 482: 113, 4505: 112, 7214: 112, 11535: 111, 18318: 111, 14536: 110, 2604: 108, 7246: 107, 3551: 105, 18297: 103, 16787: 102, 28559: 102, 13571: 100, 8790: 99, 7017: 99, 5233: 99, 10754: 99, 13240: 98, 23766: 96, 28077: 96, 10167: 96, 19086: 96, 25352: 96, 13193: 96, 23162: 95, 6804: 95, 3259: 94, 3004: 93, 21123: 93, 5847: 92, 285: 92, 23343: 91, 6468: 90, 17848: 90, 16508: 90, 15202: 88, 19252: 88, 660: 88, 16068: 88, 10101: 87, 663: 87, 23855: 86, 16988: 86, 15199: 85, 19679: 84, 5617: 84, 3564: 83, 29781: 83, 4854: 83, 7363: 83, 29779: 82, 1406: 79, 7194: 79, 20128: 79, 2247: 78, 5375: 78, 13239: 78, 5200: 77, 16741: 77, 12041: 77, 23288: 77, 29348: 75, 18170: 74, 3896: 74, 23856: 74, 29321: 74, 13161: 74, 3505: 74, 8696: 73, 1018: 73, 11392: 73, 26262: 72, 11417: 72, 10266: 72, 28517: 71, 20627: 71, 28086: 70, 15075: 70, 23291: 70, 5796: 69, 1488: 68, 5196: 68, 17849: 68, 28089: 68, 945: 68, 5155: 68, 23745: 67, 2381: 67, 10368: 66, 22899: 65, 19480: 64, 5880: 63, 16188: 62, 28253: 61, 12491: 61, 14197: 60, 12141: 59, 14428: 59, 8999: 58, 28109: 57, 12833: 57, 23302: 57, 25936: 57, 5221: 57, 8688: 55, 27506: 55, 2769: 55, 635: 52, 10675: 52, 3501: 52, 22859: 52, 8372: 52, 4682: 51, 16738: 51, 17668: 50, 4908: 50, 9110: 49, 27366: 49, 27033: 48, 22
# %%
max(genposition3_values)
min(genposition3_values)
# Out:
# 27

# %% [markdown]
# ### 0% to 50% AF

# %%
import numpy as np
q =[row for row in b if row[7]<=0.50]
qdata=np.array(q)

freq_values=qdata[:,7]
print(freq_values)
## all values are between 5% and 95% AF

# %%
genposition3_values=qdata[:,2] 
positions3=Counter(genposition3_values).keys() 
uniquevals3=len(list(positions3))
binsval3=30000
samples=Counter(qdata[:,0]).keys()

samples=Counter(qdata[:,0]).keys()

print("There are ",len(genposition3_values), " position values")
print("However there are ",uniquevals3, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs3 = dict(alpha=0.5, bins=binsval3)
plt.hist(genposition3_values, **kwargs3)
plt.ylim(0,400)
plt.title("Histogram of genome positions 0%-50%")
plt.show()

df3 = pd.Series(genposition3_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df3.columns = ['Position', 'Frequency']
print (df3)

# %% [markdown]
# ### 50% AF to 95% AF

# %%
import numpy as np
m = [row for row in b if row[7]>=0.50]
q = [row for row in m if row[7]<=0.95]
qdata=np.array(q)

freq_values=qdata[:,7]
print(freq_values)
## all values are between 5% and 95% AF

# %%
genposition3_values=qdata[:,2] 
positions3=Counter(genposition3_values).keys() 
uniquevals3=len(list(positions3))
binsval3=30000
samples=Counter(qdata[:,0]).keys()

samples=Counter(qdata[:,0]).keys()

print("There are ",len(genposition3_values), " position values")
print("However there are ",uniquevals3, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs3 = dict(alpha=0.5, bins=binsval3)
plt.hist(genposition3_values, **kwargs3)
plt.ylim(0,20)
plt.title("Histogram of genome positions 50%-95%")
plt.show()

df3 = pd.Series(genposition3_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df3.columns = ['Position', 'Frequency']
print (df3)

# %% [markdown]
# ### 50% AF to 100% AF

# %%
import numpy as np
q = [row for row in b if row[7]>=0.50]

qdata=np.array(q)

freq_values=qdata[:,7]
print(freq_values)
## all values are between 5% and 95% AF

# %%
genposition3_values=qdata[:,2] 
positions3=Counter(genposition3_values).keys() 
uniquevals3=len(list(positions3))
binsval3=30000
samples=Counter(qdata[:,0]).keys()

samples=Counter(qdata[:,0]).keys()

print("There are ",len(genposition3_values), " position values")
print("However there are ",uniquevals3, " unique position values")
print("There are ", len(list(samples)), " unique samples")

kwargs3 = dict(alpha=0.5, bins=binsval3)
plt.hist(genposition3_values, **kwargs3)
plt.ylim(0,40)
plt.title("Histogram of genome positions")
plt.show()

df3 = pd.Series(genposition3_values).value_counts().reset_index().sort_values('index').reset_index(drop=True)
        
df3.columns = ['Position', 'Frequency']
print (df3)
